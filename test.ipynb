# %%
import pandas as pd

# %%
df = pd.read_csv('all_volvo.csv')
df.info()
# Out:
# /var/folders/ds/z8w9y82x4052nsy9g05k5vc00000gp/T/ipykernel_87853/3894792868.py:1: DtypeWarning: Columns (5,12,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('all_volvo.csv')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139371 entries, 0 to 139370
# Data columns (total 15 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Unique_ID            139371 non-null  int64
#  1   Volvo OE             139371 non-null  int64
#  2   Namn                 139371 non-null  object
#  3   Kategori             139371 non-null  object
#  4   Huvudkategori        1747 non-null    object
#  5   Dubbla kategorier    34 non-null      object
#  6   Model                139371 non-null  object
#  7   Model_Year           116476 non-null  object
#  8   Engine_Type          139371 non-null  object
#  9   Skandix number       139371 non-null  int64
# ...

# %%
df_cb = pd.read_csv('dfs_combined.csv')
display(df_cb.info(), df_cb.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129940 entries, 0 to 129939
# Data columns (total 34 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Skandix number  129940 non-null  int64
#  1   Volvo OE        115835 non-null  float64
#  2   Name            129940 non-null  object
#  3   Category        129940 non-null  object
#  4   Fitment 1       105504 non-null  object
#  5   Attributes      126042 non-null  object
#  6   Fitment 2       24404 non-null   object
#  7   Fitment 3       9647 non-null    object
#  8   Fitment 4       5562 non-null    object
#  9   Fitment 5       3120 non-null    object
#  10  Fitment 6       2102 non-null    object
#  11  Fitment 7       1376 non-null    object
#  12  Fitment 8       1014 non-null    object
#  13  Fitment 9       704 non-null     object
#  14  Fitment 10      506 non-null     object
#  15  Fitment 11      378 non-null     object
# ...

# %%
df_sw = pd.read_excel('Work Svenska kategorier JJ .xlsx')
df_sw.head(2)
# Out:
#    Unique_ID  Volvo OE                         Model  \
# 0          6     10506           Volvo 120, 130, 220
# 1          6     10506  Volvo PV444, 544, P445, P210
#
#                                      Namn Huvudkategori           Kategori  \
# 0  Mutter, hjullager Slottsmutter Bakaxel           NaN  Mutter, hjullager
# 1  Mutter, hjullager Slottsmutter Bakaxel           NaN  Mutter, hjullager
#
#   Dubbla kategorier Priskategori  Unnamed: 8 Unnamed: 9
# 0               NaN          NaN  Kronmutter        NaN
# 1               NaN          NaN  Kronmutter        NaN
